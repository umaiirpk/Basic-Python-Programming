# %% [markdown]
# ## Variable
# varible is the value given to the particular location in computers memory.The value of variable can be of any Data Type e.g. string, integer, float etc.

# %% [markdown]
# ## Assingment Operator
# symbol = is an assingment operator in python which is used to to create a variable or to change the value of a variable.

# %%
marks = 10 # Here we created a variable "marks" and assign it a value 10. 
print(marks)
# Out:
# 10

# %%
# example
a = 10
b = 9
print(a*b)
# Out:
# 90

# %% [markdown]
# ## Rule for naming a variable
# Variable name can only start with a letter or underscore symbol. It can't conating blank spaces. The name only consists of letter, integer or underscore symbol only.

# %%
_name = "Muhammad Umair" # _name is a valid variable name
cgpa = 3.73 # cgpa is a valid variable name
var = "city" # 1var is an invalid variable name
my name = " Muhammad Umair" # my name is an invalid variable name
# Out:
#   Cell In[4], line 4
#     my name = " Muhammad Umair" # my name is an invalid variable name
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Note: Variable names are case sensitive

# %%
marks = 10
Marks = 10 # Both are different variables i.e. if we change the value of variable "marks", value of variable "Marks" will reamain unchanged
marks = 20
print(2*marks)
# Out:
# 40
