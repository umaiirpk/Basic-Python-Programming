# %% [markdown]
# # Command and Edit mode Cell

# %%
# Command mode cell refers to cell when it is not editable i.e. we are unable to write something
# Edit mode cell refers to cell when it is editable i.e. we can write somthing in the cell

# %% [markdown]
# # Shortcut to execute code in jupyter

# %%
# Ctrl+enter: this key will execute the code written within a cell and doesnot create a new cell automatically
# Shift+enter: this key will execute the code written within a cell and will automatically create a new cell below the executed cell.

# %% [markdown]
# # Adding and Deleting a Cell

# %%
# Being in command mode and simply pressing "a" will add a new cell above the selected cell
# Being in command mode and simple pressing "b" will add a new cell below the selected cell
# Being in command mode and simply pressing "dd" will delet the sellected cell
